# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df = nb.get_data('11111705294904516', '@SYS.USERID', 'True', {}, [],102)
df
# Out:
#    age         workclass  fnlwgt     education  educational-num      marital-status         occupation   relationship   race  gender  capital-gain  capital-loss  hours-per-week native-country income
# 0   25           Private  226802          11th                7       Never-married  Machine-op-inspct      Own-child  Black    Male             0             0              40  United-States  <=50K
# 1   38           Private   89814       HS-grad                9  Married-civ-spouse    Farming-fishing        Husband  White    Male             0             0              50  United-States  <=50K
# 2   28         Local-gov  336951    Assoc-acdm               12  Married-civ-spouse    Protective-serv        Husband  White    Male             0             0              40  United-States   >50K
# ...

# %% [markdown]
# # MySQL
#
# @ENV.MYSQL_DM_USERNAME
# @ENV.MYSQL_DM_PASSWORD
# @ENV.MYSQL_DM_HOST
# @ENV.MYSQL_DM_HTTP_PORT
# qa_test

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
nb.mysql_writer(@ENV.MYSQL_DM_USERNAME, @ENV.MYSQL_DM_PASSWORD, @ENV.MYSQL_DM_HOST, @ENV.MYSQL_DM_HTTP_PORT , 'qa_test', 'Test_V2', df)
# Out:
# Dataframe has been written to database.

# %% [markdown]
# # MongoDB
#
# @ENV.MONGODB_DM_USERNAME
# @ENV.MONGODB_DM_PASSWORD
# @ENV.MONGODB_DM_HOST
# @ENV.MONGODB_DM_PORT
# qa_test?authSource=admin
# table:wt_test

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
nb.mongo_writer(@ENV.MONGODB_DM_USERNAME, @ENV.MONGODB_DM_PASSWORD, @ENV.MONGODB_DM_HOST, @ENV.MONGODB_DM_PORT, 'qa_test?authSource=admin', 'Test_V2', df)
# Out:
# Dataframe has been written to database.

# %% [markdown]
# # ClickHouse
#
# User Name: qateam
# Password : Qid6127#d7
# http port: 8123
# tcp port : 9000
# url : db.stg.bdb.ai

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 22, 35],
    'City': ['New York', 'San Francisco', 'London', 'Paris']
}
df_New = pd.DataFrame(data)
df_New
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   22         London
# 3    David   35          Paris

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
nb.clickhouse_writer('qateam', 'Qid6127#d7', 'db.stg.bdb.ai', '9000', 'qa_test', 'Table_V1', df_New)
# Out:
# Dataframe has been written to database.

# %% [markdown]
# # PostgreSQL
#
# @ENV.POSTGRESQL_DM_HOST
# @ENV.POSTGRESQL_DM_HTTP_PORT
# @ENV.POSTGRESQL_DM_USERNA
# @ENV.POSTGRESQL_DM_PASSWORD
# DB: postgres

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
nb.postgre_writer(@ENV.POSTGRESQL_DM_USERNAME, @ENV.POSTGRESQL_DM_PASSWORD, @ENV.POSTGRESQL_DM_HOST, @ENV.POSTGRESQL_DM_HTTP_PORT, 'postgres', 'Table_V1', df)
# Out:
# Dataframe has been written to database.
