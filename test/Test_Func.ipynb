# %%
def func():
    return "Shyam"

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_DS_Lab_Mongo = nb.get_data('11561705559254274', '@SYS.USERID', 'False', {}, [])
df_DS_Lab_Mongo
# Out:
#                                         _id                                    id   brand carFamilyCode transmissionType engineCode                 startTime                  tripDate                   endTime       evTime   evDistance chargeTime      ecoTime      ecoDist    powerTime    powerDist fuelConsumption    fuelSaved     duration       length
# 0      {'$oid': '653b87d0f80d4f7eb3478e74'}  0036c946-043c-4a75-a2ed-52327bc39201  TOYOTA          679W               MT    2NR-FKE  2021-05-12T13:24:04.000Z  2021-05-12T00:00:00.000Z  2021-05-12T14:03:04.000Z         1276        14842        668         1624        31239          333         4991            2307          656         2625        43779
# ...

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_DS_Lab_ClickHouse = nb.get_data('11561705559390705', '@SYS.USERID', 'False', {}, [])
df_DS_Lab_ClickHouse
# Out:
#            App   Branch_Id  Commission Customer_Id Day_Name                                           Feedback        Holiday           Order_Date   Order_Id             Order_Item Order_Type Payment_Mode  Price  Quantity  Rating Restaurant_Name  Tax  Total_Amount
# 0           NA  LGGurugram           0     C980678   Sunday                        Greatambianceserviceletdown  Vijayadashami  2023-09-10 06:35:56  LGGM39830  TandooriChickenBurger   TakeAway         Cash    249         2       2      LeonsGrill   18           498
# 1           NA  LGGurugram           0     C375635   Sunday                    Tastespectrumservicefrustration  Vijayadashami  2023-09-10 08:08:52  LGGM31483               Coleslaw     Dinein         Cash     99         2       2      LeonsGrill   18           198
# ...
