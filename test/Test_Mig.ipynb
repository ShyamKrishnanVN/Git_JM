# %%
import New_Test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import New_Test
#
# ModuleNotFoundError: No module named 'New_Test'

# %%
import New_Test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import New_Test
#
# ModuleNotFoundError: No module named 'New_Test'

# %%
# Define the path to your .py file
file_path = @SYS.DATASANDBOX_PATH + '1104420441/Repo/test/test.py'

# Open and read the file
with open(file_path, 'r') as file:
    file_contents = file.read()

# Print the contents of the file
print(file_contents)
# Out:
# #TestUnique
