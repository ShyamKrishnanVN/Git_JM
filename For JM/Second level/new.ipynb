# %%
def new():
    from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
    nb = NotebookExecutor()
    df_postgresql_dataset_sanity_20_03 = nb.get_data('11561742451658075', '@SYS.USERID', 'False', {}, [], sheet_name = '')
    return df_postgresql_dataset_sanity_20_03
