# %%
def new_func1():
    print("New_V5")

# %%
new_func1()

# %%
def new_func2():
    print("New_V5")

# %%
new_func2()

# %%
def new_func3():
    print("New_V5")

# %%
new_func3()

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_DS_CLickHouse_test = nb.get_data('11111705296274056', '@SYS.USERID', 'False', {}, [])
df_DS_CLickHouse_test
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
#       2 nb = NotebookExecutor()
# ----> 3 df_DS_CLickHouse_test = nb.get_data('11111705296274056', '950278', 'False', {}, [])
#       4 df_DS_CLickHouse_test
#
# File /app/Notebook/DSNotebook/NotebookExecutor.py:1595, in NotebookExecutor.get_data(self, serviceID, UserID, Sandbox, filters, prep_ids, limit, spark)
#    1593     return df
#    1594 except Exception as e:
# -> 1595     raise Exception(e) from None
#
# Exception: 'queryService'
