# %%
from For_utils.Lablel_Encoder import label_encoder
import inspect
source_code = inspect.getsource(label_encoder)
print(source_code)

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df = nb.get_data('11561698303005142', '@SYS.USERID', 'False', {}, [])
df.head(12)
# Out:
#    usd_billing  gender    source  experience  candidate_id                skills         previous_organisation  id  offered_ctc expected_joining_date  previous_ctc   team  expyrsper_ctc  monthly_salary  cur_monthly_payment                 ename current_status               designation referral_of joining_status
# 0         4000  Female    Indeed          15             1  Management, Selenium                  Athenahealth   1      1800000      02-07-2018 00:00       2000000   BU 6         120000          150000               125000               Ahsan R    Transferred                QA Manager         NaN         Joined
# 1         4000  Female  Orgspire          10             2                   100                   Support.com   2      1500000      12-06-2018 00:00       2000000   BU 6         150000          125000               125000  Rajive Raveendra Pai       Resigned              QA Architect         NaN         Joined
# ...

# %%
encoded_df = label_encoder(df, 'gender', 'gender_encoded')
encoded_df
# Out:
#      usd_billing  gender    source  experience  candidate_id                      skills         previous_organisation   id  offered_ctc expected_joining_date  previous_ctc   team  expyrsper_ctc  monthly_salary  cur_monthly_payment                 ename current_status               designation referral_of joining_status  gender_encoded
# 0           4000  Female    Indeed          15             1        Management, Selenium                  Athenahealth    1      1800000      02-07-2018 00:00       2000000   BU 6         120000          150000               125000               Ahsan R    Transferred                QA Manager         NaN         Joined               1
# ...
