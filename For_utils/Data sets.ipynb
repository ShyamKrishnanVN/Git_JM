# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_DS_Lab_ClickHouse = nb.get_data('11561705035652055', '@SYS.USERID', 'False', {}, [])
df_DS_Lab_ClickHouse.head(10)

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_DS_Lab_ProtgreSQL = nb.get_data('11561702358472883', '@SYS.USERID', 'False', {}, [])
df_DS_Lab_ProtgreSQL

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_DS_Lab_MySQL = nb.get_data('11561705035891145', '@SYS.USERID', 'False', {}, [])
df_DS_Lab_MySQL
# Out:
#      Indent_No  Balance_Amount  Paid_Amount  Total_Amount       Status Payment                                        Vendor_Type            Date_Time
# 0       247939           19305            0         19305  Not Settled     N/A                           SR Enterprises(cocacola)  2019-06-01 05:00:00
# 1       248254            9000            0          9000  Not Settled     N/A                                      Basha(mutton)  2019-06-01 05:00:00
# 2       248255            3500            0          3500  Not Settled     N/A                              Narayana(Fish&prawns)  2019-06-01 05:00:00
# 3       248256            3908            0          3908  Not Settled     N/A                                         Dodla curd  2019-06-01 05:00:00
# 4       248257            4061            0          4061  Not Settled     N/A                              Poorna(paneer butter)  2019-06-01 05:00:00
# ...

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_DS_Mongo_Dataset = nb.get_data('11561704969782560', '@SYS.USERID', 'False', {}, [])
df_DS_Mongo_Dataset
# Out:
#                                       _id  Cust_Id     Age  Gender OwnHome  Married Location  Salary  Children History  Catalogs  AmountSpent           DOB
# 0    {'$oid': '656d8bae98bdbdadb98bc269'}      247     Old  Female     Own   Single      Far   47500         0    High         6          755  1.623693e+09
# 1    {'$oid': '656d8bae98bdbdadb98bc26a'}      127  Middle    Male    Rent   Single    Close   63600         0    High         6         1318           NaN
# 2    {'$oid': '656d8bae98bdbdadb98bc26b'}      479   Young  Female    Rent   Single    Close   13500         0     Low        18          296           NaN
# 3    {'$oid': '656d8bae98bdbdadb98bc26c'}      475  Middle    Male     Own  Married    Close   85600         1    High        18         2436           NaN
# 4    {'$oid': '656d8bae98bdbdadb98bc26d'}      151  Middle  Female     Own   Single    Close   68400         0    High        12         1304           NaN
# ...

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_DS_Lab_Mongo_Dataset = nb.get_data('11561705040782369', '@SYS.USERID', 'False', {}, [])
df_DS_Lab_Mongo_Dataset
# Out:
#                                         _id                                    id   brand carFamilyCode transmissionType engineCode                 startTime                  tripDate                   endTime       evTime   evDistance chargeTime      ecoTime      ecoDist    powerTime    powerDist fuelConsumption    fuelSaved     duration       length
# 0      {'$oid': '653b87d0f80d4f7eb3478e74'}  0036c946-043c-4a75-a2ed-52327bc39201  TOYOTA          679W               MT    2NR-FKE  2021-05-12T13:24:04.000Z  2021-05-12T00:00:00.000Z  2021-05-12T14:03:04.000Z         1276        14842        668         1624        31239          333         4991            2307          656         2625        43779
# ...

# %%
import pickle, os
os.getcwd()
# Out:
# '/app'

# %%
os.chdir('/app')
