# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df = nb.get_data('11111707390804200', '@SYS.USERID', 'True', {}, [])
df 
# The first function parameter refers to the service ID of the dataset.
# @SYS.USERID refers to the user ID of the current user.
# If the Sandbox key is 'false', it is referred to as a dataset, and if it's 'true', then the file is a sandbox file.
# {} refers to the filters applied to the dataset.
# [] refers to the data preparations applied to the dataset.
# After [], users can specify the number of rows to limit the headcount of the dataset with a comma separator.

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
nb.postgre_writer('qauser', 'qa@1234!', 'db.stg.bdb.ai', '5432', 'postgres', 'Postgresql_Append_Test_v1', df)
# Postgres: 
# Host: db.stg.bdb.ai
# Port: 5432
# Username: qauser
# Password: qa@1234!
# db:postgres

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_Doha_Data = nb.get_data('11111707978183523', '@SYS.USERID', 'True', {}, [])
df_Doha_Data
# Out:
#          SCHOOL_YEAR  STUDENT_ID           student_name teacher_id          teacher_name  term_id term_name  ASSESSMENT_ID                                   subject                     category     GRADE SCORE_VALUE CALCULATED_SCORE_VALUE  CALCULATED_SCORE PROFICIENCY_LEVEL
# 0               2012       13322       Stirling, Elorie        S15     Teacher15_Grade11       10        S2            334                             IB Admin Yr 1            NON_CREDIT_COURSE  Grade 11           0                    0.0               0.0              Poor
# 1               2013       13551           Choi, Sehoan        S17      Teacher17_Grade9        9        S1            339                                Study Hall            NON_CREDIT_COURSE   Grade 9           0                    0.0               0.0              Poor
# 2               2013       13558  Giselle, Hidalgo Rios        S19     Teacher19_Grade11        9        S1            339                                Study Hall            NON_CREDIT_COURSE  Grade 11           0                    0.0               0.0              Poor
# 3               2013       13577           Sadek, Farah        S17      Teacher17_Grade9        9        S1           1020                                      Math                         MATH   Grade 9           0                    0.0               0.0              Poor
# 4               2013       13577           Sadek, Farah        S17      Teacher17_Grade9        9        S1           1218                                        PE  PHYSICAL EDUCATION & HEALTH   Grade 9           0                    0.0               0.0              Poor
# ...              ...         ...                    ...        ...                   ...      ...       ...            ...                                       ...                          ...       ...         ...                    ...               ...               ...
# 1586456         2016        6695      Kohinga, Isabelle      S1903  Alexis,Avissa Samari        4        Q1             87  MAP-Math-Real and Complex Number Systems                           \N   Grade 7         249                  249.0               4.0          Advanced
# 1586457         2016        6695      Kohinga, Isabelle      S1903  Alexis,Avissa Samari        4        Q1             88       MAP-Math-Statistics and Probability                           \N   Grade 7         254                  254.0               4.0          Advanced
# 1586458         2016        6695      Kohinga, Isabelle      S1903  Alexis,Avissa Samari        4        Q1             91            MAP-Reading-Informational Text                           \N   Grade 7         245                  245.0               4.0          Advanced
# 1586459         2016        6695      Kohinga, Isabelle      S1903  Alexis,Avissa Samari        4        Q1             96                    MAP-Reading-Literature                           \N   Grade 7         242                  242.0               4.0          Advanced
# 1586460         2016        6695      Kohinga, Isabelle      S1903  Alexis,Avissa Samari       11        Y1             91            MAP-Reading-Informational Text                           \N   Grade 7         235                  235.0               4.0          Advanced
#
# [1586461 rows x 15 columns]

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
# Calculate the total number of rows in the DataFrame
total_rows = len(df_Doha_Data)
# Define the batch size
batch_size = 5000
# Calculate the number of batches
num_batches = (total_rows // batch_size) + (1 if total_rows % batch_size != 0 else 0)
# Iterate over the DataFrame in batches
for batch_num in range(num_batches):
    # Calculate the start and end indices of the current batch
    start_idx = batch_num * batch_size
    end_idx = min((batch_num + 1) * batch_size, total_rows)
    
    # Extract the current batch DataFrame
    batch_df = df_Doha_Data.iloc[start_idx:end_idx]
    
    # Write the current batch DataFrame to MySQL database
    nb.postgre_writer('qauser', 'qa@1234!', 'db.stg.bdb.ai', '5432', 'postgres', 'postgre_append_1586461', batch_df)
# Out:
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# Dataframe has been written to database.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 19
#      16 batch_df = df_Doha_Data.iloc[start_idx:end_idx]
#      18 # Write the current batch DataFrame to MySQL database
# ---> 19 nb.postgre_writer('qauser', 'qa@1234!', 'db.stg.bdb.ai', '5432', 'postgres', 'V1', batch_df)
#
# File /app/Notebook/DSNotebook/NotebookExecutor.py:2141, in NotebookExecutor.postgre_writer(self, username, password, host, port, database, tablename, df)
#    2139 except Exception as e:
#    2140     logging.error(f"Error while writing to postgress {tablename} {str(e)}")
# -> 2141     raise Exception (e) from None
#
# Exception: (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type double precision: "\N"
# LINE 1: ...oY', 8, 'Gates McG-Total', '\N', 'Grade 1', NULL, '\N', 1.0,...
#                                                              ^
#
# [SQL: INSERT INTO v1 ("SCHOOL_YEAR", "STUDENT_ID", student_name, teacher_id, teacher_name, term_id, term_name, "ASSESSMENT_ID", subject, category, "GRADE", "SCORE_VALUE", "CALCULATED_SCORE_VALUE", "CALCULATED_SCORE", "PROFICIENCY_LEVEL") VALUES (%(SCHOOL_Y ... 335237 characters truncated ... ALUE__999)s, %(CALCULATED_SCORE_VALUE__999)s, %(CALCULATED_SCORE__999)s, %(PROFICIENCY_LEVEL__999)s)]
# [parameters: {'subject__0': 'CWP - Conventions', 'SCHOOL_YEAR__0': 2021, 'CALCULATED_SCORE__0': 1.0, 'PROFICIENCY_LEVEL__0': 'Limited', 'term_name__0': 'BoY', 'SCORE_VALUE__0': '1', 'ASSESSMENT_ID__0': 140003, 'CALCULATED_SCORE_VALUE__0': '1.00', 'term_id__0': 1, 'STUDENT_ID__0': 16347, 'GRADE__0': 'Grade 2', 'student_name__0': 'Bohrt Lijeron, Bruna', 'teacher_name__0': 'West-Singh, Rani', 'teacher_id__0': 'S2250', 'category__0': '\\N', 'subject__1': 'MAP-Reading-Literal Comprehension', 'SCHOOL_YEAR__1': 2013, 'CALCULATED_SCORE__1': 1.0, 'PROFICIENCY_LEVEL__1': 'Limited', 'term_name__1': 'Q1', 'SCORE_VALUE__1': '210', 'ASSESSMENT_ID__1': 95, 'CALCULATED_SCORE_VALUE__1': '210.00', 'term_id__1': 4, 'STUDENT_ID__1': 289, 'GRADE__1': 'Grade 7', 'student_name__1': 'Albanese,Luciano', 'teacher_name__1': 'Carlson,David', 'teacher_id__1': 'S1480', 'category__1': '\\N', 'subject__2': 'MAP- Lang Usage', 'SCHOOL_YEAR__2': 2013, 'CALCULATED_SCORE__2': 1.0, 'PROFICIENCY_LEVEL__2': 'Limited', 'term_name__2': 'Q1', 'SCORE_VALUE__2': '205', 'ASSESSMENT_ID__2': 57, 'CALCULATED_SCORE_VALUE__2': '205.00', 'term_id__2': 4, 'STUDENT_ID__2': 289, 'GRADE__2': 'Grade 7', 'student_name__2': 'Albanese,Luciano', 'teacher_name__2': 'Bratton,Kasson', 'teacher_id__2': 'S1687', 'category__2': 'SOCIAL STUDIES', 'subject__3': 'MAP-Reading-Lit Response / Analysis', 'SCHOOL_YEAR__3': 2009, 'CALCULATED_SCORE__3': 1.0, 'PROFICIENCY_LEVEL__3': 'Limited', 'term_name__3': 'S1' ... 14900 parameters truncated ... 'GRADE__996': 'Grade 6', 'student_name__996': 'Jabr, Faisal', 'teacher_name__996': 'Tripp, Shannon Rae', 'teacher_id__996': 'S1879', 'category__996': 'Math 6', 'subject__997': 'US History', 'SCHOOL_YEAR__997': 2013, 'CALCULATED_SCORE__997': 1.0, 'PROFICIENCY_LEVEL__997': 'Limited', 'term_name__997': 'S1', 'SCORE_VALUE__997': '63', 'ASSESSMENT_ID__997': 411, 'CALCULATED_SCORE_VALUE__997': '63.00', 'term_id__997': 9, 'STUDENT_ID__997': 12505, 'GRADE__997': 'Grade 11', 'student_name__997': 'Hyeri, Kim', 'teacher_name__997': 'Teacher19_Grade11', 'teacher_id__997': 'S19', 'category__997': 'SOCIAL STUDIES', 'subject__998': 'MAP-Reading', 'SCHOOL_YEAR__998': 2019, 'CALCULATED_SCORE__998': 1.0, 'PROFICIENCY_LEVEL__998': 'Limited', 'term_name__998': 'Q1', 'SCORE_VALUE__998': '191', 'ASSESSMENT_ID__998': 14, 'CALCULATED_SCORE_VALUE__998': '191.00', 'term_id__998': 4, 'STUDENT_ID__998': 16371, 'GRADE__998': 'Grade 6', 'student_name__998': 'Alkhateeb,Yara', 'teacher_name__998': 'Magee, Kaitlyn', 'teacher_id__998': 'S2119', 'category__998': 'SOCIAL STUDIES', 'subject__999': 'WTW', 'SCHOOL_YEAR__999': 2021, 'CALCULATED_SCORE__999': 1.0, 'PROFICIENCY_LEVEL__999': 'Limited', 'term_name__999': 'BoY', 'SCORE_VALUE__999': '1', 'ASSESSMENT_ID__999': 9, 'CALCULATED_SCORE_VALUE__999': '1.00', 'term_id__999': 1, 'STUDENT_ID__999': 16844, 'GRADE__999': 'Grade 5', 'student_name__999': 'Wood, Lillian Carys', 'teacher_name__999': 'Dickson, Robert', 'teacher_id__999': 'S1616', 'category__999': '\\N'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
