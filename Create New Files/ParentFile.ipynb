# %%
file_path = "Repo/Create New Files/new_file.json"
 
file_content = "Test file"
 
with open(file_path, 'w') as file:
    file.write(file_content)

# %%
notebook_content = {"metadata":{"kernelspec":{"language":"python","display_name":"Python 3","name":"python3"},"language_info":{"name":"python","version":"3.10.12","mimetype":"text/x-python","codemirror_mode":{"name":"ipython","version":3},"pygments_lexer":"ipython3","nbconvert_exporter":"python","file_extension":".py"},"kaggle":{"accelerator":"none","dataSources":[],"dockerImageVersionId":30587,"isInternetEnabled":'false',"language":"python","sourceType":"notebook","isGpuEnabled":'false'}},"nbformat_minor":4,"nbformat":4,"cells":[{"cell_type":"code","source":"import pandas as pd\nnew_string  = \"Hello welcome\"","metadata":{"execution":{"iopub.status.busy":"2023-12-04T09:38:00.458922Z","iopub.execute_input":"2023-12-04T09:38:00.459641Z","iopub.status.idle":"2023-12-04T09:38:00.992199Z","shell.execute_reply.started":"2023-12-04T09:38:00.459593Z","shell.execute_reply":"2023-12-04T09:38:00.990626Z"},"trusted":'true'},"execution_count":1,"outputs":[]},{"cell_type":"code","source":"list1 = [1,2,4,5,6]\nfor i in list1:\n    print(i)","metadata":{"execution":{"iopub.status.busy":"2023-12-04T09:38:50.494443Z","iopub.execute_input":"2023-12-04T09:38:50.495235Z","iopub.status.idle":"2023-12-04T09:38:50.503492Z","shell.execute_reply.started":"2023-12-04T09:38:50.495190Z","shell.execute_reply":"2023-12-04T09:38:50.502059Z"},"trusted":'true'},"execution_count":2,"outputs":[{"name":"stdout","text":"1\n2\n4\n5\n","output_type":"stream"}]},{"cell_type":"code","source":"","metadata":{},"execution_count":'null',"outputs":[]}]}
import json
with open("Repo/Create New Files/new_file.ipynb", "w") as f:
    f.write(json.dumps(notebook_content))
