# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pandas.read_csv(url, names=names)
array = dataframe.values
X = array[:,0:9]
y = array[:,8]

# %%
url_New = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names_new = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe_new = pandas.read_csv(url, names=names)
array_new = dataframe.values
X_new = array[:,0:8]
y_new = array[:,8]

# %%
url_Latest = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names_Latest = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe_Latest = pandas.read_csv(url, names=names)
array_Latset = dataframe.values
X_Latest = array[:,0:8]
y_Latest = array[:,8]
