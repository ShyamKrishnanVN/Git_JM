# %%
import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
import pickle
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pd.read_csv(url, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]

# %%
loaded_model.transform(df)

# %%
dataframe

# %%
from Notebook.DSNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
df_Dump_Data = nb.get_data('11561697699506508', '@SYS.USERID', 'True', {}, [])

# %%
test_size = 0.33
seed = 7
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = MultinomialNB()
model.fit(X_train, Y_train);

# %%
from Notebook.bdbNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
model = nb.save_model(projectId ='684851203', UserId = '671285252', model = model, modelName = 'Model_V9.pkl')

# %%
from Notebook.bdbNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
loaded_model = nb.load_saved_model(projectId = '684851203', modelId = '696811524')

# %%
from Notebook.bdbNotebook.NotebookExecutor import NotebookExecutor
nb = NotebookExecutor()
#File extension should be with .csv/.json/.text
nb.save_artifact(projectId = '684851203', UserId = '671285252', dataframe = dataframe, name = 'sample.csv')
